# %% [markdown]
# <h1 style = "text-align: center; color: pink;">Name: Vaibhav Kumar</h1>
# <h1 style = "text-align: center; color: pink;">SAP ID: 590021603</h1>

# %% [markdown]
# <br>
# <hr>
# <br>
# <h2 style = "text-align: center;">Lab Experiments</h2>
# <h2 style = "text-align: center;">Experiment: Functions</h2>

# %% [markdown]
# <h2><b>Question: </b>Write a Python function to find the maximum and minimum numbers from a sequence of numbers.</h2>
# <h2>Code:</h2>

# %%
def minimumMaximum(numbers):
    if not numbers:
        return None, None
    
    maximumValue = numbers[0]
    minimumValue = numbers[0]

    for num in numbers[1:]:
        if num > maximumValue:
            maximumValue = num
        elif num < minimumValue:
            minimumValue = num

    return maximumValue, minimumValue

nums = [12, 9, 25, 15]
maximumNumber, minimumNumber = minimumMaximum(nums)
print(f"Maximum: {maximumNumber}, Minimum: {minimumNumber}")
# Out:
# Maximum: 25, Minimum: 9
