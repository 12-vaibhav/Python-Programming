# %% [markdown]
# <h1 style="text-align: center; color: pink;">Name: Vaibhav Kumar</h1>
# <h1 style="text-align: center; color: pink;">SAP ID: 590021603</h1>
#
# <h2>Chapter: Classes & objects in Python</h2>
# <br>
# <hr>
# <br>

# %% [markdown]
# <h2>OOP Concepts, Classes & Objects, Methods</h2>
# <h2><b>Question: </b>Why OOP?</h2>
# <p><b>Object-Oriented Programming (OOP) </b>organizes code around <b style="color: pink;">objects</b> (data + behavior). It is useful when: </p>
#
# <ul>
#     <li>Software is large and needs modular design</li>
# </ul>
