# %% [markdown]
# <h1 style="color: pink; text-align: center;">Name: Vaibhav Kumar</h1>
# <h1 style="color: pink; text-align: center;">SAP ID: 590021603</h1>

# %% [markdown]
# <hr>
# <br>
# <h1>Lab Experiments</h1>
# <h2>Python Installation and starting with Python</h2>

# %% [markdown]
# <h2>Write a program to print strings in the given  manner: </h2>

# %%
print("Hello Everyone !!!"); print("Hello \nWorld"); print("Hello\n\tWorld"); print("Vaibhav\'s date of birth is 12/07/2007")
# Out:
# Hello Everyone !!!
# Hello
# World
# Hello
# 	World
# Vaibhav's date of birth is 12/07/2007

# %% [markdown]
# <br>
# <hr>
# <br>
# <h2>Declare a string variable called x and assign it the value "Hello". Print out the value of x.</h2>

# %%
x = "Hello"
print(x)
# Out:
# Hello

# %% [markdown]
# <br>
# <hr>
# <br>
# <h2>Take different data types and print values using print function.</h2>

# %%
a = "Vaibhav Kumar"
b = 12072007
c = 12.15

print(a)
print(b)
print(c)
# Out:
# Vaibhav Kumar
# 12072007
# 12.15

# %% [markdown]
# <br>
# <hr>
# <br>
# <h2>Take two variables, a and b. Assign your firstname and lastname. Print your Name after adding your Firstname and Lastname together.</h2>

# %%
a = "Vaibhav "
b = "Kumar"
print(a + b)
# Out:
# Vaibhav Kumar

# %% [markdown]
# <br>
# <hr>
# <br>
# <h2>Declare three variables, consisting of your Firstname, Lastname and Nickname. Write a Program that prints out your Firstname, then your Nickname in parenthesis and then your Lastname.</h2>

# %%
FirstName = "Vaibhav"
LastName = "Kumar"
NickName = "(Veer)"

print(FirstName, NickName, LastName)
# Out:
# Vaibhav (Veer) Kumar

# %% [markdown]
# <br>
# <hr>
# <br>
# <h2>Declare and assign values to suitable variables and print in the following way.</h2>

# %%
Name = "Vaibhav Kumar"
SapId = 590021603
Day = 12
Month = "July"
Year = 2007
Address = "UPES\n\tBidholi Campus\n\tPincode: 248007"
Program = "\nBachelors of Computer Applications"
Semester = 2

print("Name: ", Name, "\nSAP ID:" , SapId); print("Date Of Birth:", Day, Month, Year, "\nAddress:", Address); print("Semester: ", Semester)
# Out:
# Name:  Vaibhav Kumar
# SAP ID: 590021603
# Date Of Birth: 12 July 2007
# Address: UPES
# 	Bidholi Campus
# 	Pincode: 248007
# Semester:  2

# %% [markdown]
# <br>
# <hr>
