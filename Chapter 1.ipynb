# %% [markdown]
# <h1>Name: Vaibhav Kumar</h1>
# <h1>SAP ID: 590021603</h1>
#
# <br><br>

# %% [markdown]
# <h1>Chapter 1 Getting Started with Python</h1>

# %%
a = 20
print(a)
# Out:
# 20

# %% [markdown]
# <h2>Introduction to Python</h2>

# %% [markdown]
# <p>Python is an interpreted, object-oriented, high-level programming language with dynamic semantics. It's high-level built in data structures, combined with dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together. Python is simple, easy to learn syntax emphasizes, readability and therefore reduces the cost of program maintenance. Python supports modules and packages, which encourages program modularity and code reuse. The Python interpreter and the extensive standard library are available in source or binary form without charge for all major platforms and can be freely disturbed.
# </p>

# %% [markdown]
# <h2>What is interactive programming in Python?</h2>
#
# <p>When we can run a programming directly from terminal and the output is instant. We don't need a helper command to run the script.</p>

# %% [markdown]
# <h2>What is script programming in Python?</h2>
#
# <p>When we submit the script to the compiler using a helper command. In the case of python the terminal command is "python - filename"</p>

# %% [markdown]
# <h2>Interactive Python in Jupyter</h2>

# %%
a = 2
b = 6
print("The product of", a , "and", b, "is", a * b)
# Out:
# The product of 2 and 6 is 12

# %% [markdown]
# <h2>Script Mode in Jupyter Notebook</h2>

# %%
# !python python.py
# Out:
# 1

# %% [markdown]
# <h2>Dynamic Types in Python</h2>
# <p>Python as a script or language is what &quot;Dynamically Typed&quot;, meaning the variable are declared during runtime and there datatype is not explicitly specified.</p>

# %%
a = 12

# %%
a = "Vaibhav"

# %%
a[1]
# Out:
# 'a'

# %%
a[1] = "v"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a[1] = "v"
#
# TypeError: 'str' object does not support item assignment
